# %% [markdown]
# ## Oppgave 3
#
# Listen `biler` inneholder informasjon om de 10 mest solgte bilene i Norge i 2023.
#
# > OBS! Kjør kodeblokken under før du begynner å programmere!
#
# 1. Bruk listen og lag en fin utskrift med informasjon om Tesla Model Y
# 2. Bruk listen og lag en fin utskrift med informasjon om alle bilene på topplisten
# 3. Av bilene som er på topplisten hvor mange solgte biler er av merke Toyota?
# 4. Lag en ordbok som teller antall solgte biler for hvert bilmerke på topplisten
# 5. Tegn et stolpediagram som viser antall solgte biler på topplisten gruppert etter bilmerke

# %%
biler =  [
    {"bilmerke": "Tesla", "modell": "Model Y", "land": "USA", "antall_solgte": 23088, "andel_solgte": 18.2},
    {"bilmerke": "Volkswagen", "modell": "ID.4", "land": "Tyskland", "antall_solgte": 6614, "andel_solgte": 5.2},
    {"bilmerke": "Skoda", "modell": "Enyaq", "land": "Tsjekkia", "antall_solgte": 5740, "andel_solgte": 4.5},
    {"bilmerke": "Toyota", "modell": "bZ4X", "land": "Japan", "antall_solgte": 5395, "andel_solgte": 4.2},
    {"bilmerke": "Volvo", "modell": "XC40", "land": "Sverige", "antall_solgte": 5025, "andel_solgte": 4.0},
    {"bilmerke": "Ford", "modell": "Mustang Mach-E", "land": "USA", "antall_solgte": 3792, "andel_solgte": 3.0},
    {"bilmerke": "Toyota", "modell": "Yaris", "land": "Japan", "antall_solgte": 3582, "andel_solgte": 2.8},
    {"bilmerke": "Toyota", "modell": "RAV4", "land": "Japan", "antall_solgte": 3457, "andel_solgte": 2.7},
    {"bilmerke": "Volkswagen", "modell": "ID.3", "land": "Tyskland", "antall_solgte": 3141, "andel_solgte": 2.5}
]
# Kjør denne kodeblokken før du begynner! (shift + enter) / (Trykk på play)

# %%
# 1. Bruk ordboken og lag en fin utskrift med informasjon om Tesla Model Y

print(biler[0])
# Out:
# {'bilmerke': 'Tesla', 'modell': 'Model Y', 'land': 'USA', 'antall_solgte': 23088, 'andel_solgte': 18.2}

# %%
# 2. Bruk listen og lag en fin utskrift med informasjon om alle bilene på topplisten


for bil in biler:
    print(f"Bilmerke: {bil['bilmerke']} - Modell: {bil['modell']} - Land: {bil['land']} - Antall solgte: {bil['antall_solgte']} - Andel solgte: {bil['andel_solgte']}")
# Out:
# Bilmerke: Tesla - Modell: Model Y - Land: USA - Antall solgte: 23088 - Andel solgte: 18.2
# Bilmerke: Volkswagen - Modell: ID.4 - Land: Tyskland - Antall solgte: 6614 - Andel solgte: 5.2
# Bilmerke: Skoda - Modell: Enyaq - Land: Tsjekkia - Antall solgte: 5740 - Andel solgte: 4.5
# Bilmerke: Toyota - Modell: bZ4X - Land: Japan - Antall solgte: 5395 - Andel solgte: 4.2
# Bilmerke: Volvo - Modell: XC40 - Land: Sverige - Antall solgte: 5025 - Andel solgte: 4.0
# Bilmerke: Ford - Modell: Mustang Mach-E - Land: USA - Antall solgte: 3792 - Andel solgte: 3.0
# Bilmerke: Toyota - Modell: Yaris - Land: Japan - Antall solgte: 3582 - Andel solgte: 2.8
# Bilmerke: Toyota - Modell: RAV4 - Land: Japan - Antall solgte: 3457 - Andel solgte: 2.7
# Bilmerke: Volkswagen - Modell: ID.3 - Land: Tyskland - Antall solgte: 3141 - Andel solgte: 2.5

# %%
# 3. Av bilene som er på topplisten hvor mange solgte biler var av merke Toyota?

antall_solgte = 0

for bil in biler:
    if bil['bilmerke'] == "Toyota":
        antall_solgte += bil['antall_solgte']
print(f"Antall Toyotaer Solgt: {antall_solgte}")
# Out:
# Antall Toyotaer Solgt: 12434

# %%
# 4. Lag en ordbok som teller antall solgte biler for hvert bilmerke på topplisten

antall_bilermerker = {}

for bil in biler:
    bilmerke = bil['bilmerke']
    if bilmerke not in antall_bilermerker:
        antall_bilermerker[bilmerke] = 1
    else:
        antall_bilermerker[bilmerke] += 1

antall_bilermerker
# Out:
# {'Tesla': 1, 'Volkswagen': 2, 'Skoda': 1, 'Toyota': 3, 'Volvo': 1, 'Ford': 1}

# %%
# 5. Tegn et stolpediagram som viser antall solgte biler på topplisten gruppert etter bilmerke

import matplotlib.pyplot as plt

bilmerker = list(antall_bilermerker.keys())
antall = list(antall_bilermerker.values())

bilmerke = bilmerke
antall = antall

plt.plot(bilmerker, antall)

# %% [markdown]
# ## Oppgave 4
#
# 1. Åpne filen oscar2024.json med python, og print ordboken til "Actor in a Leading Role" (den første prisen)
# 2. Print alle de nominerte filmene
# 3. Hvor mange nominasjoner har filmen "Barbie"
# 4. Hvilken film har flest nominasjoner, hvor mange har den?
# 5. Lag en oversikt som presenterer de ti filmene med flest nominasjoner og antall nominasjoner

# %%
# 1. Åpne filen oscar2024.json med python og print ordboken til "Actor in a Leading Role"

import json
fil = open("oscar2024.json", encoding="utf-8")
filmer = json.load(fil)
fil.close()


filmer[0]
# Out:
# {'name': 'Actor in a Leading Role',
#  'nominations': [{'name': 'Bradley Cooper', 'movie': 'Maestro'},
#   {'name': 'Colman Domingo', 'movie': 'Rustin'},
#   {'name': 'Paul Giamatti', 'movie': 'The Holdovers'},
#   {'name': 'Cillian Murphy', 'movie': 'Oppenheimer'},
#   {'name': 'Jeffrey Wright', 'movie': 'American Fiction'}]}

# %%
# 2. Print alle filmene de nominerte filmene
# >  Filmer som er nominert til flere priser kan printes flere ganger

for film in filmer:
    print(f"{film['nominations']}")
# Out:
# [{'name': 'Bradley Cooper', 'movie': 'Maestro'}, {'name': 'Colman Domingo', 'movie': 'Rustin'}, {'name': 'Paul Giamatti', 'movie': 'The Holdovers'}, {'name': 'Cillian Murphy', 'movie': 'Oppenheimer'}, {'name': 'Jeffrey Wright', 'movie': 'American Fiction'}]
# [{'name': 'Sterling K. Brown', 'movie': 'American Fiction'}, {'name': 'Robert De Niro', 'movie': 'Killers of the Flower Moon'}, {'name': 'Robert Downey Jr.', 'movie': 'Oppenheimer'}, {'name': 'Ryan Gosling', 'movie': 'Barbie'}, {'name': 'Mark Ruffalo', 'movie': 'Poor Things'}]
# [{'name': 'Annette Bening', 'movie': 'Nyad'}, {'name': 'Lily Gladstone', 'movie': 'Killers of the Flower Moon'}, {'name': 'Sandra Hüller', 'movie': 'Anatomy of a Fall'}, {'name': 'Carey Mulligan', 'movie': 'Maestro'}, {'name': 'Emma Stone', 'movie': 'Poor Things'}]
# [{'name': 'Emily Blunt', 'movie': 'Oppenheimer'}, {'name': 'Danielle Brooks', 'movie': 'The Color Purple'}, {'name': 'America Ferrera', 'movie': 'Barbie'}, {'name': 'Jodie Foster', 'movie': 'Nyad'}, {'name': "Da'Vine Joy Randolph", 'movie': 'The Holdovers'}]
# [{'name': 'Hayao Miyazaki and Toshio Suzuki', 'movie': 'The Boy and the Heron'}, {'name': 'Peter Sohn and Denise Ream', 'movie': 'Elemental'}, {'name': 'Nick Bruno, Troy Quane, Karen Ryan and Julie Zackary', 'movie': 'Nimona'}, {'name': 'Pablo Berger, Ibon Cormenzana, Ignasi Estapé and Sandra Tapia Díaz', 'movie': 'Robot Dreams'}, {'name': 'Kemp Powers, Justin K. Thompson, Phil Lord, Christopher Miller and Amy Pascal', 'movie': 'Spider-Man: Across the Spider-Verse'}]
# [{'name': 'Edward Lachman', 'movie': 'El Conde'}, {'name': 'Rodrigo Prieto', 'movie': 'Killers of the Flower Moon'}, {'name': 'Matthew Libatique', 'movie': 'Maestro'}, {'name': 'Hoyte van Hoytema', 'movie': 'Oppenheimer'}, {'name': 'Robbie Ryan', 'movie': 'Poor Things'}]
# [{'name': 'Jacqueline Durran', 'movie': 'Barbie'}, {'name': 'Jacqueline West', 'movie': 'Killers of the Flower Moon'}, {'name': 'Janty Yates and Dave Crossman', 'movie': 'Napoleon'}, {'name': 'Ellen Mirojnick', 'movie': 'Oppenheimer'}, {'name': 'Holly Waddington', 'movie': 'Poor Things'}]
# [{'name': 'Justine Triet', 'movie': 'Anatomy of a Fall'}, {'name': 'Martin Scorsese', 'movie': 'Killers of the Flower Moon'}, {'name': 'Christopher Nolan', 'movie': 'Oppenheimer'}, {'name': 'Yorgos Lanthimos', 'movie': 'Poor Things'}, {'name': 'Jonathan Glazer', 'movie': 'The Zone of Interest'}]
# [{'name': 'Moses Bwayo, Christopher Sharp and John Battsek', 'movie': "Bobi Wine: The People's President"}, {'name': 'Kaouther Ben Hania and Nadim Cheikhrouha', 'movie': 'Four Daughters'}, {'name': 'Nisha Pahuja, Cornelia Principe and David Oppenheim', 'movie': 'To Kill a Tiger'}, {'name': 'Mstyslav Chernov, Michelle Mizner and Raney Aronson-Rath', 'movie': '20 Days in Mariupol'}]
# [{'name': 'Sheila Nevins and Trish Adlesic', 'movie': 'The ABCs of Book Banning'}, {'name': 'John Hoffman and Christine Turner', 'movie': 'The Barber of Little Rock'}, {'name': 'S. Leo Chiang and Jean Tsien', 'movie': 'Island in Between'}, {'name': 'Ben Proudfoot and Kris Bowers', 'movie': 'The Last Repair Shop'}, {'name': 'Sean Wang and Sam Davis', 'movie': 'Nǎi Nai & Wài Pó'}]
# [{'name': 'Laurent Sénéchal', 'movie': 'Anatomy of a Fall'}, {'name': 'Kevin Tent', 'movie': 'The Holdovers'}, {'name': 'Thelma Schoonmaker', 'movie': 'Killers of the Flower Moon'}, {'name': 'Jennifer Lame', 'movie': 'Oppenheimer'}, {'name': 'Yorgos Mavropsaridis', 'movie': 'Poor Things'}]
# [{'name': 'Italy', 'movie': 'Io Capitano'}, {'name': 'Japan', 'movie': 'Perfect Days'}, {'name': 'Spain', 'movie': 'Society of the Snow'}, {'name': 'Germany', 'movie': "The Teachers' Lounge"}, {'name': 'United Kingdom', 'movie': 'The Zone of Interest'}]
# [{'name': 'Ben LeClair, Nikos Karamigios, Cord Jefferson and Jermaine Johnson', 'movie': 'American Fiction'}, {'name': 'Marie-Ange Luciani and David Thion', 'movie': 'Anatomy of a Fall'}, {'name': 'David Heyman, Margot Robbie, Tom Ackerley and Robbie Brenner', 'movie': 'Barbie'}, {'name': 'Mark Johnson', 'movie': 'The Holdovers'}, {'name': 'Dan Friedkin, Bradley Thomas, Martin Scorsese and Daniel Lupi', 'movie': 'Killers of the Flower Moon'}, {'name': 'Bradley Cooper, Steven Spielberg, Fred Berner, Amy Durning and Kristie Macosko Krieger', 'movie': 'Maestro'}, {'name': 'Emma Thomas, Charles Roven and Christopher Nolan', 'movie': 'Oppenheimer'}, {'name': 'David Hinojosa, Christine Vachon and Pamela Koffler', 'movie': 'Past Lives'}, {'name': 'Ed Guiney, Andrew Lowe, Yorgos Lanthimos and Emma Stone', 'movie': 'Poor Things'}, {'name': 'James Wilson', 'movie': 'The Zone of Interest'}]
# [{'name': 'Karen Hartley Thomas, Suzi Battersby and Ashra Kelly-Blue', 'movie': 'Golda'}, {'name': 'Kazu Hiro, Kay Georgiou and Lori McCoy-Bell', 'movie': 'Maestro'}, {'name': 'Luisa Abel', 'movie': 'Oppenheimer'}, {'name': 'Nadia Stacey, Mark Coulier and Josh Weston', 'movie': 'Poor Things'}, {'name': 'Ana López-Puigcerver, David Martí and Montse Ribé', 'movie': 'Society of the Snow'}]
# [{'name': 'Laura Karpman', 'movie': 'American Fiction'}, {'name': 'John Williams', 'movie': 'Indiana Jones and the Dial of Destiny'}, {'name': 'Robbie Robertson', 'movie': 'Killers of the Flower Moon'}, {'name': 'Ludwig Göransson', 'movie': 'Oppenheimer'}, {'name': 'Jerskin Fendrix', 'movie': 'Poor Things'}]
# [{'name': 'Diane Warren', 'movie': 'The Fire Inside', 'lyricist': 'Diane Warren'}, {'name': 'Mark Ronson and Andrew Wyatt', 'movie': "I'm Just Ken", 'lyricist': 'Mark Ronson and Andrew Wyatt'}, {'name': 'Jon Batiste and Dan Wilson', 'movie': 'It Never Went Away', 'lyricist': 'Jon Batiste and Dan Wilson'}, {'name': 'Scott George', 'movie': 'Wahzhazhe (A Song For My People)', 'lyricist': 'Scott George'}, {'name': "Billie Eilish and Finneas O'Connell", 'movie': 'What Was I Made For?', 'lyricist': "Billie Eilish and Finneas O'Connell"}]
# [{'name': 'Sarah Greenwood', 'movie': 'Barbie'}, {'name': 'Jack Fisk', 'movie': 'Killers of the Flower Moon'}, {'name': 'Arthur Max', 'movie': 'Napoleon'}, {'name': 'Ruth De Jong', 'movie': 'Oppenheimer'}, {'name': 'James Price and Shona Heath', 'movie': 'Poor Things'}]
# [{'name': 'Tal Kantor and Amit R. Gicelter', 'movie': 'Letter to a Pig'}, {'name': 'Jerusha Hess and Jared Hess', 'movie': 'Ninety-Five Senses'}, {'name': 'Yegane Moghaddam', 'movie': 'Our Uniform'}, {'name': 'Stéphanie Clément and Marc Rius', 'movie': 'Pachyderme'}, {'name': 'Dave Mullins and Brad Booker', 'movie': 'WAR IS OVER! Inspired by the Music of John & Yoko'}]
# [{'name': 'Misan Harriman and Nicky Bentham', 'movie': 'The After'}, {'name': 'Vincent René-Lortie and Samuel Caron', 'movie': 'Invincible'}, {'name': 'Lasse Lyskjær Noer and Christian Norlyk', 'movie': 'Knight of Fortune'}, {'name': 'Nazrin Choudhury and Sara McFarlane', 'movie': 'Red, White and Blue'}, {'name': 'Wes Anderson and Steven Rales', 'movie': 'The Wonderful Story of Henry Sugar'}]
# [{'name': 'Ian Voigt, Erik Aadahl, Ethan Van der Ryn, Tom Ozanich and Dean Zupancic', 'movie': 'The Creator'}, {'name': 'Steven A. Morrow, Richard King, Jason Ruder, Tom Ozanich and Dean Zupancic', 'movie': 'Maestro'}, {'name': 'Chris Munro, James H. Mather, Chris Burdon and Mark Taylor', 'movie': 'Mission: Impossible - Dead Reckoning Part One'}, {'name': "Willie Burton, Richard King, Gary A. Rizzo and Kevin O'Connell", 'movie': 'Oppenheimer'}, {'name': 'Tarn Willers and Johnnie Burn', 'movie': 'The Zone of Interest'}]
# [{'name': 'Jay Cooper, Ian Comley, Andrew Roberts and Neil Corbould', 'movie': 'The Creator'}, {'name': 'Takashi Yamazaki, Kiyoko Shibuya, Masaki Takahashi and Tatsuji Nojima', 'movie': 'Godzilla Minus One'}, {'name': 'Stephane Ceretti, Alexis Wajsbrot, Guy Williams and Theo Bialek', 'movie': 'Guardians of the Galaxy Vol. 3'}, {'name': 'Alex Wuttke, Simone Coco, Jeff Sutherland and Neil Corbould', 'movie': 'Mission: Impossible - Dead Reckoning Part One'}, {'name': 'Charley Henley, Luc-Ewen Martin-Fenouillet, Simone Coco and Neil Corbould', 'movie': 'Napoleon'}]
# [{'name': 'Cord Jefferson', 'movie': 'American Fiction'}, {'name': 'Greta Gerwig & Noah Baumbach', 'movie': 'Barbie'}, {'name': 'Christopher Nolan', 'movie': 'Oppenheimer'}, {'name': 'Tony McNamara', 'movie': 'Poor Things'}, {'name': 'Jonathan Glazer', 'movie': 'The Zone of Interest'}]
# [{'name': 'Justine Triet and Arthur Harari', 'movie': 'Anatomy of a Fall'}, {'name': 'David Hemingson', 'movie': 'The Holdovers'}, {'name': 'Bradley Cooper & Josh Singer', 'movie': 'Maestro'}, {'name': 'Samy Burch; Story by Samy Burch & Alex Mechanik', 'movie': 'May December'}, {'name': 'Celine Song', 'movie': 'Past Lives'}]

# %%
# 3. Hvor mange nominasjoner har filmen "Barbie"

barbie_nominasjoner = 0

for film in filmer:
    if film['nominations'] == 'Barbie':
        barbie_nominasjoner += 1
print(f"Antall Barbie Nominasjoner: {barbie_nominasjoner}")
# Out:
# Antall Barbie Nominasjoner: 0

# %%
# 4. Hvilken film har flest nominasjoner, hvor mange har den?

antall_liste = list(antall.items())
antall_sortert = sorted(antall_liste, key=lambda film: film[1])
film_flest = antall_sortert[-1] 
print(f"Filmen med flest nominasjoner er {film_flest[0]} den har {film_flest[1]}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[129], line 3
#       1 # 4. Hvilken film har flest nominasjoner, hvor mange har den?
# ----> 3 antall_liste = list(antall.items())
#       4 antall_sortert = sorted(antall_liste, key=lambda film: film[1])
#       5 film_flest = antall_sortert[-1]
#
# AttributeError: 'list' object has no attribute 'items'

# %%
# 5. Lag en utskrift som viser de ti filmene med flest nominasjoner og antall nominasjoner
